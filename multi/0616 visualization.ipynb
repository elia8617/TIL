# %%
# !cd
# Out:
# C:\Users\kim\Desktop\2021-K-Digital-Training-main\SQL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tips = pd.read_csv('.\\tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(tips)

# %%
tips.groupby(tips['day']).count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %%
tips.groupby([tips['day'],tips['time']]).count()
# Out:
#              total_bill  tip  sex  smoker  size
# day  time
# Fri  Dinner          12   12   12      12    12
#      Lunch            7    7    7       7     7
# Sat  Dinner          87   87   87      87    87
# Sun  Dinner          76   76   76      76    76
# Thur Dinner           1    1    1       1     1
#      Lunch           61   61   61      61    61

# %%
t_bill = tips.total_bill
#tips.total_bill.plot(kind='box')

# %%
plt.boxplot(t_bill, labels=['Bill'])
#plt.boxplot(t_bill, set_labels='bill')


plt.show()

# %%
import seaborn as sns

# %%
t_sns_bill = sns.boxplot(x='total_bill', data=tips)

# %%
t_tips = tips.tip

# %%
plt.boxplot(t_tips, labels=['tip'])
plt.show()

# %%
t_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
sns.regplot(x="total_bill",y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x="size", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
tips.total_bill.hist()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(x=t_bill, bins=20)
# Out:
# C:\Users\kim\anaconda3\envs\multi\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(x=t_bill, bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(x=t_tips, bins=20)
# Out:
# C:\Users\kim\anaconda3\envs\multi\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
size_tip=pd.crosstab(index=tips['size'], columns='count')

# %%
pd.crosstab(index=tips['size'], columns='count')

# %%
pd.crosstab(index=tips['size'], columns='count').plot()
# Out:
# <AxesSubplot:xlabel='size'>

# %%
size_tip.plot.bar()
# Out:
# <AxesSubplot:xlabel='size'>

# %%
tip_rate=tips['tip']/tips['total_bill']

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips['tip_rate']=(tips['tip']/tips['total_bill'])

# %%
tips.describe()
# Out:
#        total_bill         tip        size    tip_rate
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672    0.160803
# std      8.902412    1.383638    0.951100    0.061072
# min      3.070000    1.000000    1.000000    0.035638
# 25%     13.347500    2.000000    2.000000    0.129127
# 50%     17.795000    2.900000    2.000000    0.154770
# 75%     24.127500    3.562500    3.000000    0.191475
# max     50.810000   10.000000    6.000000    0.710345

# %%
top_tip = (tips['tip_rate'] >= 0.7)

# %%
tips[tips['tip_rate']>0.7]
# Out:
#      total_bill   tip   sex smoker  day    time  size  tip_rate
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2  0.710345

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
#  7   tip_rate    244 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 15.4+ KB

# %%
import pandas_profiling

# %%
tips.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.12.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-06-16 07:14:43.064252&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#결론, 
#본 식당은 일행 SIZE 및 TOTAL BILL SIZE에 대한 TIP RATE 가 음의 상관관계가 있는것으로 미루어보아 2~3명의 인원이 방문했을때가 가장 효과적인 매장 운영이 가능한것으로 보인다
# 따라서 소규모 인원을 중심으로 2인테이블 구성 또는 바 테이블 구성등을 통해 소규모고객을 타겟으로 운영하는걸 권고한다.

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_rate
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587

# %%
tips['sex']=tips['sex'].replace({'Female':0, 'Male':1})

# %%
tips.head(3)
# Out:
#    total_bill   tip  sex smoker  day    time  size  tip_rate
# 0       16.99  1.01    0     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    1     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    1     No  Sun  Dinner     3  0.166587

# %%
tips['smoker']=tips['smoker'].replace({'No':0, 'Yes':1})

# %%
tips.head(3)
# Out:
#    total_bill   tip  sex  smoker  day    time  size  tip_rate
# 0       16.99  1.01    0       0  Sun  Dinner     2  0.059447
# 1       10.34  1.66    1       0  Sun  Dinner     3  0.160542
# 2       21.01  3.50    1       0  Sun  Dinner     3  0.166587

# %%
tips['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
tips['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
tips['day']=tips['day'].replace({'Thur':0, 'Fri':1, 'Sat':1, 'Sun':1})

# %%
tips['time']=tips['time'].replace({'Lunch':0, 'Dinner':1})

# %%
tips.head(3)
# Out:
#    total_bill   tip  sex  smoker  day  time  size  tip_rate
# 0       16.99  1.01    0       0    1     1     2  0.059447
# 1       10.34  1.66    1       0    1     1     3  0.160542
# 2       21.01  3.50    1       0    1     1     3  0.166587

# %%
tips.corr()
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill    1.000000  0.675734  0.144877  0.085721  0.138174  0.183118
# tip           0.675734  1.000000  0.088862  0.005929  0.095879  0.121629
# sex           0.144877  0.088862  1.000000  0.002816  0.194445  0.205231
# smoker        0.085721  0.005929  0.002816  1.000000  0.128534  0.054921
# day           0.138174  0.095879  0.194445  0.128534  1.000000  0.917996
# time          0.183118  0.121629  0.205231  0.054921  0.917996  1.000000
# size          0.598315  0.489299  0.086195 -0.133178  0.072598  0.103411
# tip_rate     -0.338624  0.342370 -0.069475  0.030820 -0.004530 -0.033914
#
#                 size  tip_rate
# total_bill  0.598315 -0.338624
# tip         0.489299  0.342370
# sex         0.086195 -0.069475
# smoker     -0.133178  0.030820
# day         0.072598 -0.004530
# time        0.103411 -0.033914
# size        1.000000 -0.142860
# tip_rate   -0.142860  1.000000

# %%
tips.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.12.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-06-16 06:03:59.809814&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
tips['day'].plot

# %%
tips.groupby(tips['day']).count()
# Out:
#      total_bill  tip  sex  smoker  time  size  tip_rate
# day
# 0            62   62   62      62    62    62        62
# 1           182  182  182     182   182   182       182

# %%
sns.pairplot(tips.loc[:,['total_bill','tip']])

# %%
sns.pairplot(tips.loc[:,['total_bill', 'size']])

# %%
sns.pairplot(tips.loc[:,['day', 'size']])

# %%
sns.pairplot(tips.loc[:,['time', 'tip']])
